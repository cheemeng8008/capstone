# %% [markdown]
# ## Melbourne City Data

# %% [markdown]
# #### I will be using Melbourne City's data to get all areas in Melbourne City

# %%
df_melbourne_city=pd.read_csv('melbourne_city_data.csv')
df_melbourne_city.head()
# Out:
#    Unnamed: 0           Place  Code    Country          Admin2  Latitude  \
# 0           0       Melbourne  3000  Australia  MELBOURNE CITY   -37.813
# 1           1  East Melbourne  3002  Australia  MELBOURNE CITY   -37.813
# 2           2  West Melbourne  3003  Australia  MELBOURNE CITY   -37.809
# 3           3       Melbourne  3004  Australia  MELBOURNE CITY   -37.842
# 4           4       Docklands  3008  Australia  MELBOURNE CITY   -37.818
#
#    Longitude
# 0    144.961
# 1    144.984
# 2    144.947
# 3    144.976
# 4    144.944

# %% [markdown]
# ##### The data contains all the areas in Melbourne City together with its Postal Code and its coordinates

# %% [markdown]
# #### I will be using the top 100 venues in Melbourne City using Foursquare

# %%
df_melbourne_city_venues=pd.read_csv('melbourne_city_venues.csv')
df_melbourne_city_venues.head()
# Out:
#    Unnamed: 0 Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0           0    Melbourne                -37.813                 144.961
# 1           1    Melbourne                -37.813                 144.961
# 2           2    Melbourne                -37.813                 144.961
# 3           3    Melbourne                -37.813                 144.961
# 4           4    Melbourne                -37.813                 144.961
#
#                        Venue  Venue Latitude  Venue Longitude  \
# 0                    Tipo 00      -37.813527       144.961978
# 1  Shortstop Coffee & Donuts      -37.811240       144.961000
# 2         Brother Baba Budan      -37.813445       144.962137
# 3            Kirk's Wine Bar      -37.813661       144.961351
# 4                 Brick Lane      -37.811341       144.959816
#
#        Venue Category
# 0  Italian Restaurant
# 1          Donut Shop
# 2         Coffee Shop
# 3            Wine Bar
# 4                Café

# %% [markdown]
# ##### It contains all the top 100 venues in Melbourne City with its respective neighborhood/area, its category and its coordinates

# %% [markdown]
# ## Bangkok Data

# %% [markdown]
# #### I will be using Bangkok's data to get all areas/places in Bangkok

# %%
df_bangkok=pd.read_csv('bangkok_data.csv')
df_bangkok.head()
# Out:
#    Unnamed: 0                 Place   Code   Country   Admin1  Latitude  \
# 0           0               Wattana  10110  Thailand  Bangkok    13.708
# 1           1               Yannawa  10120  Thailand  Bangkok    13.708
# 2           2         Thawi Wattana  10170  Thailand  Bangkok    13.767
# 3           3  Pom Prap Sattru Phai  10100  Thailand  Bangkok    13.733
# 4           4        Samphanthawong  10100  Thailand  Bangkok    13.733
#
#    Longitude
# 0    100.456
# 1    100.456
# 2    100.450
# 3    100.500
# 4    100.500

# %% [markdown]
# ##### The data contains all the areas/places in Bangkok together with its coordinates and their respective postal code.

# %% [markdown]
# #### I will be using data of the top 100 venues in Bangkok within 500m using Foursquare data

# %%
df_bangkok_venues=pd.read_csv('bangkok_venues.csv')
df_bangkok_venues.head()
# Out:
#    Unnamed: 0 Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0           0      Wattana                 13.708                 100.456
# 1           1      Wattana                 13.708                 100.456
# 2           2      Wattana                 13.708                 100.456
# 3           3      Wattana                 13.708                 100.456
# 4           4      Wattana                 13.708                 100.456
#
#                           Venue  Venue Latitude  Venue Longitude  \
# 0   ก๋วยเตี๋ยวต้มยำตำลึง นายเอก       13.709675       100.453821
# 1        Starbucks (สตาร์บัคส์)       13.709113       100.452060
# 2   7-Eleven (เซเว่น อีเลฟเว่น)       13.710411       100.455035
# 3  ร้านอาหารหนองคายเสนา (ป้าสุ)       13.710441       100.455170
# 4              sorry i'm hungry       13.710255       100.454076
#
#           Venue Category
# 0           Noodle House
# 1            Coffee Shop
# 2      Convenience Store
# ...

# %% [markdown]
# ##### It contains all the top 100 venues in Bangkok with its respective neighborhood/area, its category and its coordinates
